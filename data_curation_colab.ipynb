#   inflating: abo-images-small/images/small/ff/ffff4040.jpg
#   inflating: abo-images-small/images/small/ff/ffff87d7.jpg
#   inflating: abo-images-small/images/small/ff/ffffc378.jpg
#   inflating: abo-images-small/images/small/ff/ffffd5c6.jpg
#   inflating: abo-images-small/images/small/ff/ffffe50e.jpg
#   inflating: abo-listings/LICENSE-CC-BY-4.0.txt
#   inflating: abo-listings/listings/README.md
#   inflating: abo-listings/listings/metadata/listings_0.json
#   inflating: abo-listings/listings/metadata/listings_1.json
#   inflating: abo-listings/listings/metadata/listings_2.json
#   inflating: abo-listings/listings/metadata/listings_3.json
#   inflating: abo-listings/listings/metadata/listings_4.json
#   inflating: abo-listings/listings/metadata/listings_5.json
#   inflating: abo-listings/listings/metadata/listings_6.json
#   inflating: abo-listings/listings/metadata/listings_7.json
#   inflating: abo-listings/listings/metadata/listings_8.json
#   inflating: abo-listings/listings/metadata/listings_9.json
#   inflating: abo-listings/listings/metadata/listings_a.json
#   inflating: abo-listings/listings/metadata/listings_b.json
#   inflating: abo-listings/listings/metadata/listings_c.json
#   inflating: abo-listings/listings/metadata/listings_d.json
#   inflating: abo-listings/listings/metadata/listings_e.json
#   inflating: abo-listings/listings/metadata/listings_f.json

# %%
# it is used to read image.csv file in abo-images-small data which has image id
import pandas as pd
file_path = pd.read_csv('/content/abo-images-small/images/metadata/images.csv')

# %%
# used to read all the metadata from listings and combine them to one as all_meta_data
import pandas as pd
import string

num_suffixes = list(map(str, range(10)))
alpha_suffixes = list(string.ascii_lowercase[:6])
suffixes = num_suffixes + alpha_suffixes

meta_data_list = []

for suffix in suffixes:
    path = f'/content/abo-listings/listings/metadata/listings_{suffix}.json'
    df = pd.read_json(path, lines=True)
    df.rename(columns={'main_image_id': 'image_id'}, inplace=True)
    meta_data_list.append(df)

all_meta_data = pd.concat(meta_data_list, ignore_index=True)

# %%
# used to create rows for all image_ids and other_image_ids as image_ids so that each image_id is recordered as different (has multiple data)
import pandas as pd

df = pd.DataFrame(all_meta_data)

def combine_ids(row):
    other_ids = row['other_image_id']
    # other_image_id is taken as list as it contains image ids
    if isinstance(other_ids, list):
        return [row['image_id']] + other_ids
    else:
        return [row['image_id']]

df['combined_image_ids'] = df.apply(combine_ids, axis=1)

df_exploded = df.explode('combined_image_ids').reset_index(drop=True)

df_exploded['image_id'] = df_exploded['combined_image_ids']

df_exploded.drop(columns=['combined_image_ids'], inplace=True)

print(df_exploded)
# Out:
#                                                     brand  \
# 0           [{'language_tag': 'nl_NL', 'value': 'find.'}]
# 1           [{'language_tag': 'nl_NL', 'value': 'find.'}]
# 2           [{'language_tag': 'nl_NL', 'value': 'find.'}]
# 3           [{'language_tag': 'nl_NL', 'value': 'find.'}]
# 4       [{'language_tag': 'es_MX', 'value': 'AmazonBas...
# ...                                                   ...
# 711223      [{'language_tag': 'en_CA', 'value': 'find.'}]
# 711224      [{'language_tag': 'en_CA', 'value': 'find.'}]
# 711225      [{'language_tag': 'en_CA', 'value': 'find.'}]
# 711226      [{'language_tag': 'en_CA', 'value': 'find.'}]
# 711227      [{'language_tag': 'en_CA', 'value': 'find.'}]
#
#                                              bullet_point  \
# 0       [{'language_tag': 'nl_NL', 'value': 'Schoen in...
# 1       [{'language_tag': 'nl_NL', 'value': 'Schoen in...
# 2       [{'language_tag': 'nl_NL', 'value': 'Schoen in...
# 3       [{'language_tag': 'nl_NL', 'value': 'Schoen in...
# 4       [{'language_tag': 'es_MX', 'value': 'White Pow...
# ...                                                   ...
# 711223  [{'language_tag': 'en_CA', 'value': 'Elastic s...
# 711224  [{'language_tag': 'en_CA', 'value': 'Elastic s...
# 711225  [{'language_tag': 'en_CA', 'value': 'Elastic s...
# 711226  [{'language_tag': 'en_CA', 'value': 'Elastic s...
# 711227  [{'language_tag': 'en_CA', 'value': 'Elastic s...
#
#                                                     color     item_id  \
# 0       [{'language_tag': 'nl_NL', 'value': 'Veelkleur...  B06X9STHNG
# 1       [{'language_tag': 'nl_NL', 'value': 'Veelkleur...  B06X9STHNG
# 2       [{'language_tag': 'nl_NL', 'value': 'Veelkleur...  B06X9STHNG
# 3       [{'language_tag': 'nl_NL', 'value': 'Veelkleur...  B06X9STHNG
# 4       [{'language_tag': 'es_MX', 'value': 'White Pow...  B07P8ML82R
# ...                                                   ...         ...
# 711223                                                NaN  B07WSKB7LR
# 711224                                                NaN  B07WSKB7LR
# 711225                                                NaN  B07WSKB7LR
# 711226                                                NaN  B07WSKB7LR
# 711227                                                NaN  B07WSKB7LR
#
#                                                 item_name  \
# 0       [{'language_tag': 'nl_NL', 'value': 'Amazon-me...
# 1       [{'language_tag': 'nl_NL', 'value': 'Amazon-me...
# 2       [{'language_tag': 'nl_NL', 'value': 'Amazon-me...
# 3       [{'language_tag': 'nl_NL', 'value': 'Amazon-me...
# 4       [{'language_tag': 'es_MX', 'value': '22" Botto...
# ...                                                   ...
# 711223  [{'language_tag': 'en_CA', 'value': 'Amazon Br...
# 711224  [{'language_tag': 'en_CA', 'value': 'Amazon Br...
# 711225  [{'language_tag': 'en_CA', 'value': 'Amazon Br...
# 711226  [{'language_tag': 'en_CA', 'value': 'Amazon Br...
# 711227  [{'language_tag': 'en_CA', 'value': 'Amazon Br...
#
#                                               model_name  \
# 0          [{'language_tag': 'nl_NL', 'value': '37753'}]
# 1          [{'language_tag': 'nl_NL', 'value': '37753'}]
# 2          [{'language_tag': 'nl_NL', 'value': '37753'}]
# 3          [{'language_tag': 'nl_NL', 'value': '37753'}]
# 4                                                    NaN
# ...                                                  ...
# 711223  [{'language_tag': 'en_CA', 'value': 'Clermont'}]
# 711224  [{'language_tag': 'en_CA', 'value': 'Clermont'}]
# 711225  [{'language_tag': 'en_CA', 'value': 'Clermont'}]
# 711226  [{'language_tag': 'en_CA', 'value': 'Clermont'}]
# 711227  [{'language_tag': 'en_CA', 'value': 'Clermont'}]
#
#                             model_number         model_year  \
# 0                [{'value': '12-05-04'}]  [{'value': 2017}]
# 1                [{'value': '12-05-04'}]  [{'value': 2017}]
# 2                [{'value': '12-05-04'}]  [{'value': 2017}]
# 3                [{'value': '12-05-04'}]  [{'value': 2017}]
# 4           [{'value': 'AB5013-R22-10'}]                NaN
# ...                                  ...                ...
# 711223  [{'value': 'Clermont Fly Knit'}]                NaN
# 711224  [{'value': 'Clermont Fly Knit'}]                NaN
# 711225  [{'value': 'Clermont Fly Knit'}]                NaN
# 711226  [{'value': 'Clermont Fly Knit'}]                NaN
# 711227  [{'value': 'Clermont Fly Knit'}]                NaN
#
#                    product_type  \
# 0          [{'value': 'SHOES'}]
# 1          [{'value': 'SHOES'}]
# 2          [{'value': 'SHOES'}]
# 3          [{'value': 'SHOES'}]
# 4       [{'value': 'HARDWARE'}]
# ...                         ...
# 711223     [{'value': 'SHOES'}]
# 711224     [{'value': 'SHOES'}]
# 711225     [{'value': 'SHOES'}]
# 711226     [{'value': 'SHOES'}]
# 711227     [{'value': 'SHOES'}]
#
#                                                     style  ...  \
# 0       [{'language_tag': 'nl_NL', 'value': 'Gesloten-...  ...
# 1       [{'language_tag': 'nl_NL', 'value': 'Gesloten-...  ...
# 2       [{'language_tag': 'nl_NL', 'value': 'Gesloten-...  ...
# 3       [{'language_tag': 'nl_NL', 'value': 'Gesloten-...  ...
# 4        [{'language_tag': 'es_MX', 'value': '10 pares'}]  ...
# ...                                                   ...  ...
# 711223   [{'language_tag': 'en_CA', 'value': 'Clermont'}]  ...
# 711224   [{'language_tag': 'en_CA', 'value': 'Clermont'}]  ...
# 711225   [{'language_tag': 'en_CA', 'value': 'Clermont'}]  ...
# 711226   [{'language_tag': 'en_CA', 'value': 'Clermont'}]  ...
# 711227   [{'language_tag': 'en_CA', 'value': 'Clermont'}]  ...
#
#                                               item_weight material  \
# 0                                                     NaN      NaN
# 1                                                     NaN      NaN
# 2                                                     NaN      NaN
# 3                                                     NaN      NaN
# 4       [{'normalized_value': {'unit': 'pounds', 'valu...      NaN
# ...                                                   ...      ...
# 711223                                                NaN      NaN
# 711224                                                NaN      NaN
# 711225                                                NaN      NaN
# 711226                                                NaN      NaN
# 711227                                                NaN      NaN
#
#        fabric_type color_code product_description spin_id 3dmodel_id pattern  \
# 0              NaN        NaN                 NaN     NaN        NaN     NaN
# 1              NaN        NaN                 NaN     NaN        NaN     NaN
# 2              NaN        NaN                 NaN     NaN        NaN     NaN
# 3              NaN        NaN                 NaN     NaN        NaN     NaN
# 4              NaN        NaN                 NaN     NaN        NaN     NaN
# ...            ...        ...                 ...     ...        ...     ...
# 711223         NaN        NaN                 NaN     NaN        NaN     NaN
# 711224         NaN        NaN                 NaN     NaN        NaN     NaN
# 711225         NaN        NaN                 NaN     NaN        NaN     NaN
# 711226         NaN        NaN                 NaN     NaN        NaN     NaN
# 711227         NaN        NaN                 NaN     NaN        NaN     NaN
#
#        finish_type item_shape
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 711223         NaN        NaN
# 711224         NaN        NaN
# 711225         NaN        NaN
# 711226         NaN        NaN
# 711227         NaN        NaN
#
# [711228 rows x 28 columns]

# %%
# to check that image_ids are changed properly
df_exploded["image_id"]
# Out:
# 0         81iZlv3bjpL
# 1         91mIRxgziUL
# 2         91eqBkW06wL
# 3         A1BHZSKNbkL
# 4         619y9YG9cnL
#              ...
# 711223    81fnxlzmiYL
# 711224    81YNklsz4dL
# 711225    A1+VHY23fgL
# 711226    913lKMbp7OL
# 711227    91Tl-bK1vvL
# Name: image_id, Length: 711228, dtype: object

# %%
# changed here we are taking from duplicated rows the one which has most data i.e which has max non-NaN columns
tdf = df_exploded
#tdf = tdf.drop_duplicates(subset='image_id', keep='first')  # 'first' keeps the first occurrence, 'last' keeps the last
tdf = tdf.loc[tdf.isna().sum(axis=1).groupby(tdf['image_id']).idxmin()]

# Display the updated DataFrame
print(tdf)
# Out:
#                                                     brand  \
# 581401        [{'language_tag': 'it_IT', 'value': 'UMI'}]
# 457442        [{'language_tag': 'it_IT', 'value': 'UMI'}]
# 271559        [{'language_tag': 'es_ES', 'value': 'UMI'}]
# 620522        [{'language_tag': 'es_ES', 'value': 'UMI'}]
# 624642     [{'language_tag': 'en_US', 'value': 'Solimo'}]
# ...                                                   ...
# 572022      [{'language_tag': 'en_US', 'value': 'Rivet'}]
# 294706  [{'language_tag': 'es_ES', 'value': 'Stone & B...
# 197017  [{'language_tag': 'en_US', 'value': 'Stone & B...
# 22216   [{'language_tag': 'en_US', 'value': 'Stone & B...
# 143002  [{'language_tag': 'en_US', 'value': 'Stone & B...
#
#                                              bullet_point  \
# 581401                                                NaN
# 457442                                                NaN
# 271559                                                NaN
# 620522                                                NaN
# 624642  [{'language_tag': 'en_US', 'value': 'One 500 m...
# ...                                                   ...
# 572022  [{'language_tag': 'ko_KR', 'value': '낮은 각도의 팔,...
# 294706                                                NaN
# 197017  [{'language_tag': 'pt_BR', 'value': 'O clássic...
# 22216   [{'language_tag': 'zh_CN', 'value': '经典的英式卷臂使这...
# 143002  [{'language_tag': 'es_US', 'value': 'El clásic...
#
#                                                     color     item_id  \
# 581401                                                NaN  B07Y7M8LV7
# 457442                                                NaN  B07Y7M4JZ2
# 271559                                                NaN  B07ZTFRVTT
# 620522                                                NaN  B07ZTFC41S
# 624642                                                NaN  B07CMMZT7R
# ...                                                   ...         ...
# 572022  [{'language_tag': 'ko_KR', 'standardized_value...  B07B4M6CN1
# 294706  [{'language_tag': 'es_ES', 'standardized_value...  B075X3S2Z1
# 197017  [{'language_tag': 'zh_CN', 'value': '灰亚麻'}, {'...  B07B4FZJVP
# 22216   [{'language_tag': 'ko_KR', 'standardized_value...  B07B4MHTM6
# 143002  [{'language_tag': 'ko_KR', 'standardized_value...  B07B4M35MF
#
#                                                 item_name  \
# 581401  [{'language_tag': 'it_IT', 'value': 'Glasses O...
# 457442  [{'language_tag': 'it_IT', 'value': 'Set of 6 ...
# 271559  [{'language_tag': 'es_ES', 'value': 'Tumblers/...
# 620522  [{'language_tag': 'es_ES', 'value': 'Blue Wate...
# 624642  [{'language_tag': 'en_US', 'value': 'Amazon Br...
# ...                                                   ...
# 572022  [{'language_tag': 'zh_CN', 'value': 'Amazon Br...
# 294706  [{'language_tag': 'es_ES', 'value': 'Stone & B...
# 197017  [{'language_tag': 'zh_CN', 'value': '亚马逊品牌 - S...
# 22216   [{'language_tag': 'zh_CN', 'value': '亚马逊品牌 - S...
# 143002  [{'language_tag': 'zh_CN', 'value': '亚马逊品牌 - S...
#
#                                                model_name  \
# 581401                                                NaN
# 457442                                                NaN
# 271559                                                NaN
# 620522                                                NaN
# 624642                                                NaN
# ...                                                   ...
# 572022  [{'language_tag': 'ko_KR', 'value': 'Berkshire...
# 294706                                                NaN
# 197017                                                NaN
# 22216                                                 NaN
# 143002                                                NaN
#
#                         model_number model_year            product_type  \
# 581401                           NaN        NaN  [{'value': 'KITCHEN'}]
# 457442                           NaN        NaN  [{'value': 'KITCHEN'}]
# 271559                           NaN        NaN  [{'value': 'KITCHEN'}]
# 620522                           NaN        NaN  [{'value': 'KITCHEN'}]
# 624642                           NaN        NaN  [{'value': 'GROCERY'}]
# ...                              ...        ...                     ...
# 572022  [{'value': 'No. 14-S-Gray'}]        NaN     [{'value': 'SOFA'}]
# 294706    [{'value': 'HW-T3501SSD'}]        NaN     [{'value': 'LAMP'}]
# 197017      [{'value': 'K76400NPS'}]        NaN     [{'value': 'SOFA'}]
# 22216       [{'value': 'K76400NPS'}]        NaN     [{'value': 'SOFA'}]
# 143002      [{'value': 'K76400NPS'}]        NaN     [{'value': 'SOFA'}]
#
#                                                     style  ...  \
# 581401                                                NaN  ...
# 457442                                                NaN  ...
# 271559                                                NaN  ...
# 620522                                                NaN  ...
# 624642                                                NaN  ...
# ...                                                   ...  ...
# 572022                                                NaN  ...
# 294706                                                NaN  ...
# 197017  [{'language_tag': 'ko_KR', 'value': '변천하는'}, {...  ...
# 22216   [{'language_tag': 'ko_KR', 'value': '변천하는'}, {...  ...
# 143002                                                NaN  ...
#
#                                               item_weight  \
# 581401                                                NaN
# 457442                                                NaN
# 271559                                                NaN
# 620522                                                NaN
# 624642  [{'normalized_value': {'unit': 'pounds', 'valu...
# ...                                                   ...
# 572022  [{'normalized_value': {'unit': 'pounds', 'valu...
# 294706  [{'normalized_value': {'unit': 'pounds', 'valu...
# 197017  [{'normalized_value': {'unit': 'pounds', 'valu...
# 22216   [{'normalized_value': {'unit': 'pounds', 'valu...
# 143002  [{'normalized_value': {'unit': 'pounds', 'valu...
#
#                                                  material  \
# 581401                                                NaN
# 457442                                                NaN
# 271559                                                NaN
# 620522                                                NaN
# 624642                                                NaN
# ...                                                   ...
# 572022  [{'language_tag': 'zh_CN', 'value': '布料'}, {'l...
# 294706                                                NaN
# 197017  [{'language_tag': 'zh_CN', 'value': '亚麻'}, {'l...
# 22216   [{'language_tag': 'zh_CN', 'value': '灰石色'}, {'...
# 143002  [{'language_tag': 'zh_CN', 'value': '灰石色'}, {'...
#
#                                               fabric_type color_code  \
# 581401                                                NaN        NaN
# 457442                                                NaN        NaN
# 271559                                                NaN        NaN
# 620522                                                NaN        NaN
# 624642                                                NaN        NaN
# ...                                                   ...        ...
# 572022  [{'language_tag': 'en_US', 'value': '70% Polye...  [#B1A9A3]
# 294706                                                NaN        NaN
# 197017                                                NaN  [#A99D90]
# 22216                                                 NaN  [#BAAEA2]
# 143002                                                NaN  [#BCB09B]
#
#        product_description   spin_id  3dmodel_id pattern finish_type  \
# 581401                 NaN       NaN         NaN     NaN         NaN
# 457442                 NaN       NaN         NaN     NaN         NaN
# 271559                 NaN       NaN         NaN     NaN         NaN
# 620522                 NaN       NaN         NaN     NaN         NaN
# 624642                 NaN       NaN         NaN     NaN         NaN
# ...                    ...       ...         ...     ...         ...
# 572022                 NaN  f690fd1e  B07B4M6CN1     NaN         NaN
# 294706                 NaN  562dd1fc  B075X3S2Z1     NaN         NaN
# 197017                 NaN  0ea74964  B07B4FZJVP     NaN         NaN
# 22216                  NaN  579e4497  B07B4MHTM6     NaN         NaN
# 143002                 NaN  54041437  B07B4M35MF     NaN         NaN
#
#        item_shape
# 581401        NaN
# 457442        NaN
# 271559        NaN
# 620522        NaN
# 624642        NaN
# ...           ...
# 572022        NaN
# 294706        NaN
# 197017        NaN
# 22216         NaN
# 143002        NaN
#
# [398170 rows x 28 columns]

# %%
final_merged = pd.merge(file_path, tdf, on='image_id', how='left')

# %%
df = final_merged

# %%
import os
image_folder = '/content/abo-images-small/images/small/'
df['path'] = df['path'].apply(lambda p: os.path.join(image_folder, p))

# %%
df.columns
# Out:
# Index(['image_id', 'height', 'width', 'path', 'brand', 'bullet_point', 'color',
#        'item_id', 'item_name', 'model_name', 'model_number', 'model_year',
#        'product_type', 'style', 'other_image_id', 'item_keywords', 'country',
#        'marketplace', 'domain_name', 'node', 'item_dimensions', 'item_weight',
#        'material', 'fabric_type', 'color_code', 'product_description',
#        'spin_id', '3dmodel_id', 'pattern', 'finish_type', 'item_shape'],
#       dtype='object')

# %%
print(df.head())
# Out:
#       image_id  height  width  \
# 0  010-mllS7JL     106    106
# 1  01dkn0Gyx0L     122    122
# 2  01sUPg0387L     111    111
# 3  1168jc-5r1L     186    186
# 4  11RUV5Fs65L      30    500
#
#                                                 path  \
# 0  /kaggle/input/vr-miniproject-2/abo-images-smal...
# 1  /kaggle/input/vr-miniproject-2/abo-images-smal...
# 2  /kaggle/input/vr-miniproject-2/abo-images-smal...
# 3  /kaggle/input/vr-miniproject-2/abo-images-smal...
# 4  /kaggle/input/vr-miniproject-2/abo-images-smal...
#
#                                             brand  \
# 0     [{'language_tag': 'it_IT', 'value': 'UMI'}]
# 1     [{'language_tag': 'it_IT', 'value': 'UMI'}]
# 2     [{'language_tag': 'es_ES', 'value': 'UMI'}]
# 3     [{'language_tag': 'es_ES', 'value': 'UMI'}]
# 4  [{'language_tag': 'en_US', 'value': 'Solimo'}]
#
#                                         bullet_point color     item_id  \
# 0                                                NaN   NaN  B07Y7M8LV7
# 1                                                NaN   NaN  B07Y7M4JZ2
# 2                                                NaN   NaN  B07ZTFRVTT
# 3                                                NaN   NaN  B07ZTFC41S
# 4  [{'language_tag': 'en_US', 'value': 'One 500 m...   NaN  B07CMMZT7R
#
#                                            item_name model_name  ...  \
# 0  [{'language_tag': 'it_IT', 'value': 'Glasses O...        NaN  ...
# 1  [{'language_tag': 'it_IT', 'value': 'Set of 6 ...        NaN  ...
# 2  [{'language_tag': 'es_ES', 'value': 'Tumblers/...        NaN  ...
# 3  [{'language_tag': 'es_ES', 'value': 'Blue Wate...        NaN  ...
# 4  [{'language_tag': 'en_US', 'value': 'Amazon Br...        NaN  ...
#
#                                          item_weight material fabric_type  \
# 0                                                NaN      NaN         NaN
# 1                                                NaN      NaN         NaN
# 2                                                NaN      NaN         NaN
# 3                                                NaN      NaN         NaN
# 4  [{'normalized_value': {'unit': 'pounds', 'valu...      NaN         NaN
#
#   color_code product_description spin_id 3dmodel_id pattern finish_type  \
# 0        NaN                 NaN     NaN        NaN     NaN         NaN
# 1        NaN                 NaN     NaN        NaN     NaN         NaN
# 2        NaN                 NaN     NaN        NaN     NaN         NaN
# 3        NaN                 NaN     NaN        NaN     NaN         NaN
# 4        NaN                 NaN     NaN        NaN     NaN         NaN
#
#   item_shape
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 31 columns]

# %%
# one can change number of columns by mentioning below (before i assumed we need to generate only 1 question so there were less columns) you can add more columns by seeing the above output
# chagne in the api code: add the column values which u are taking
df = df[["image_id","height","width","path","color","item_name","brand","item_keywords", "product_type","material","fabric_type","pattern","product_description", "item_shape","color"]]

# %%
# one need to change here the indexes take a gap of 1000
# .... : 0 - 1L
# .... : 1L - 2L
# .... : 2L - 3L
subset_df = df.loc[102000:103501]

# %%
## in these u need to add the columns which u have added previously
import base64
import os
import requests
from tqdm import tqdm
import time
import random
import pandas as pd

API_KEY = ""
questions_list = []
answers_list = []

N = 1500
max_retries = 3
retry_delay = 10

for idx, row in tqdm(subset_df.head(N).iterrows(), total=N):
    # in these u need to add the columns which u have added in df
    image_path = row['path']
    item_keywords = row['item_keywords']
    item_name = row['item_name']
    product_type = row['product_type']
    material = row['material']
    fabric_type = row['fabric_type']
    pattern = row['pattern']
    product_description = row['product_description']
    item_shape = row['item_shape']
    color = row['color']
    height = row['height']
    brand= row['brand']
    width = row['width']

    time.sleep(10)

    attempt = 0
    while attempt < max_retries:
        try:
            with open(image_path, "rb") as image_file:
                image_base64 = base64.b64encode(image_file.read()).decode("utf-8")
           

            prompt_text = (
                f"Given this product image and its metadata:\n"
                f"- Item Name: {item_name}\n"
                f"- Keywords: {item_keywords}\n"
                f"- Product Type: {product_type}\n"
                f"- Material: {material}\n"
                f"- Fabric Type: {fabric_type}\n"
                f"- Pattern: {pattern}\n"
                f"- Description: {product_description}\n"
                f"- Brand: {brand}\n"
                f"- Shape: {item_shape}\n"
                f"- Color: {color}\n\n"
                f"Generate between 3 and 7 high-quality question-answer pairs that are suitable for training a BLIP (Bootstrapped Language-Image Pretraining) model on Amazon-style e-commerce data.\n\n"
                f"Important constraints:\n"
                f"1. The answer to each question must be a single English word.\n"
                f"2. Avoid yes/no, true/false, subjective, or numerical questions (e.g., price, size, quantity).\n"
                f"3. Focus on visual or descriptive aspects (e.g., shape, texture, color, pattern, type, material, visible design features).\n"
                f"4. If metadata is missing, rely solely on the image to generate relevant and grounded questions.\n\n"
                f"Output format:\n"
                f"Each line should contain one question and its answer, separated by ' / '. For example:\n"
                f"What is the main color of the item? / Red\n"
                f"What kind of pattern does the item have? / Striped"
            )
            
            



            prompt = {
                "contents": [{
                    "parts": [
                        {"text": prompt_text},
                        {
                            "inline_data": {
                                "mime_type": "image/jpeg",
                                "data": image_base64
                            }
                        }
                    ]
                }]
            }

            url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={API_KEY}"
            headers = {"Content-Type": "application/json"}
            response = requests.post(url, headers=headers, json=prompt)
            response_json = response.json()

            if "candidates" in response_json:
                output_text = response_json["candidates"][0]["content"]["parts"][0]["text"]
                break
            elif "error" in response_json:
                error_msg = response_json['error']['message']
                if "overloaded" in error_msg.lower():
                    attempt += 1
                    if attempt < max_retries:
                        print(f"Model overloaded. Retrying... Attempt {attempt} of {max_retries}")
                        time.sleep(random.uniform(30, 50))
                        continue
                    else:
                        output_text = f"API Error: {error_msg} (Max retries reached)"
                else:
                    output_text = f"API Error: {error_msg}"
                break
            else:
                output_text = "Unexpected response format"
                break

        except requests.exceptions.RequestException as e:
            output_text = f"Request Error: {str(e)}"
            attempt += 1
            if attempt < max_retries:
                print(f"Retrying... Attempt {attempt} of {max_retries}.")
                time.sleep(random.uniform(50, 80))
            else:
                output_text = "Max retries reached. Skipping."
        except Exception as e:
            output_text = f"Exception: {str(e)}"
            break

    # Parse and extract Q/A
    q_list = []
    a_list = []
    if "/" in output_text and "API Error" not in output_text and "Exception" not in output_text and "Unexpected" not in output_text:
        lines = output_text.strip().splitlines()
        for line in lines:
            if " / " in line:
                q, a = line.split(" / ")
                q_list.append(q.strip())
                a_list.append(a.strip())
    else:
        # Error or bad output, store empty lists
        q_list = []
        a_list = []

    questions_list.append(q_list)
    answers_list.append(a_list)
subset_df.loc[subset_df.head(N).index, "qa_questions"] = pd.Series(questions_list, index=subset_df.head(N).index)
subset_df.loc[subset_df.head(N).index, "qa_answers"] = pd.Series(answers_list, index=subset_df.head(N).index)
print(subset_df[["path", "qa_questions", "qa_answers"]].head(N))
# Out:
#  19%|█▉        | 282/1500 [53:01<3:46:13, 11.14s/it]
# Retrying... Attempt 1 of 3.
# 100%|██████████| 1500/1500 [4:41:59<00:00, 11.28s/it]
#                                                      path  \
# 102000  /content/abo-images-small/images/small/cd/cd9b...
# 102001  /content/abo-images-small/images/small/59/59d2...
# 102002  /content/abo-images-small/images/small/c4/c4fe...
# 102003  /content/abo-images-small/images/small/15/153d...
# 102004  /content/abo-images-small/images/small/cf/cfa4...
# ...                                                   ...
# 103495  /content/abo-images-small/images/small/bd/bd60...
# 103496  /content/abo-images-small/images/small/ec/ec23...
# 103497  /content/abo-images-small/images/small/ee/ee2e...
# 103498  /content/abo-images-small/images/small/bd/bdfe...
# 103499  /content/abo-images-small/images/small/64/645c...
#
#                                              qa_questions  \
# 102000  [What is the sole material?, What is the patte...
# 102001  [What is the lens shade?, What is the goggle m...
# 102002  [What is the cover's background?, What is the ...
# 102003  [What is the cover's color?, What is the cover...
# 102004  [What is the product container's material?, Wh...
# ...                                                   ...
# 103495  [What is the item?, What shape is gem?, Where ...
# 103496  [What is the background color?, What feature i...
# 103497  [What is the shelf's backing?, What is the she...
# 103498  [What material is the pan?, What is the pan's ...
# 103499  [What color is the first binder?, What color i...
#
#                                                qa_answers
# 102000                          [Rubber, Textured, White]
# 102001  [Smoked, Plastic, Black, Rectangular, Matte, G...
# 102002  [Pink, Black, Diamonds, Swirls, Colorful, Flor...
# 102003               [Black, Smooth, No, Round, Vertical]
# 102004         [Plastic, Rectangular, Orange, Clear, 365]
# ...                                                   ...
# 103495  [Ring, Square, Finger, Shiny, Prong, Crystal, ...
# 103496  [White, Water, Blue, Printed, Hard, Upper, Pla...
# 103497   [Metal, Wood, Flowers, Black, Brown, Wall, Pink]
# 103498  [Metal, Silver, Cylindrical, Yes, Modern, Shin...
# 103499  [Pink, Yellow, Blue, Metal, Triangular, Smooth...
#
# [1500 rows x 3 columns]
# <ipython-input-14-61a63323e68e>:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.loc[subset_df.head(N).index, "qa_questions"] = pd.Series(questions_list, index=subset_df.head(N).index)
# <ipython-input-14-61a63323e68e>:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.loc[subset_df.head(N).index, "qa_answers"] = pd.Series(answers_list, index=subset_df.head(N).index)

# %%
# subset_df.loc[subset_df.head(156).index, "qa_questions"] = pd.Series(questions_list, index=subset_df.head(156).index)
# subset_df.loc[subset_df.head(156).index, "qa_answers"] = pd.Series(answers_list, index=subset_df.head(156).index)

qna = subset_df[["image_id","path","height","width", "qa_questions", "qa_answers"]]
qna.to_csv("qna_output_102000_103501.csv", index=False)

# %%
from google.colab import files
files.download("qna_output_102000_103501.csv")

# %%
df = pd.read_csv("/content/cleaned_qna_colab.csv")

# %%
df.head()
# Out:
#       image_id                                               path  height  \
# 0  71fu9sfmtNL  /content/abo-images-small/images/small/04/048a...    2200
# 1  71fuEz4S6DL  /content/abo-images-small/images/small/92/92b2...    2560
# 2  71fuFfPO0RL  /content/abo-images-small/images/small/6a/6ab4...    1611
# 3  71fuMNqdSsL  /content/abo-images-small/images/small/ac/ace5...    1500
# 4  71fuQf5T+8L  /content/abo-images-small/images/small/23/2324...    1118
#
#    width                                       qa_questions  \
# 0   1879  ['What color is the background?', 'What is the...
# 1   2560  ['What material is this?', "What is the chair'...
# 2   1364  ['What color is the holder?', 'What color is t...
# 3   1500  ["What is the item's shape?", "What is the ite...
# 4   2560  ['What is the handle pattern?', 'What shape is...
#
#                                           qa_answers
# 0  ['Yellow', 'Dress', 'Microphone', 'Blonde', 'B...
# 1  ['Plastic', 'Blue', 'Yes', 'Chair', 'Somewhat'...
# 2  ['Orange', 'Black', 'Cartridge', 'Ink', 'Recta...
# 3  ['Square', 'Soft', 'Yellow', 'Horizontal', 'Tr...
# 4  ['Wood', 'Round', 'Brown', 'Swirl', 'Kadhai', ...
